# %% [markdown]
# <a href="https://colab.research.google.com/github/jakeagreer/BTE320/blob/main/Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework

# %% [markdown]
# ## Assignment 1: Quality Control
#
# A quality control manager would like to find the average weight of a list of weights. Prior experience indicates that the first two measures are atypical, and the practice is to exclude these from the average calculation.
#
# Write a program that calculates the average of a list of numbers that given as inputs from the user, excluding the first two values.
#
# For your program, you must define and use the following functions:
# - `getValues(n)`: Prompt the user for `n` values, returns the list
# - `calcAverage(alist)`: Calculates the average from the list

# %%
def getValues(n):
  nlist = []
  i = 0
  while i < n:
    num = int(input(f"Enter number {i+1} for the list: "))
    nlist.append(num)
    i += 1
  return nlist

def calcAverage(alist):
  average = sum(alist[2:]) / (len(alist) - 2)
  return average

def main():
  n = int(input("How many numbers will be in your list: "))
  alist = getValues(n)
  avg = calcAverage(alist)
  print("The Average calculator of:", alist, "is", avg)

main()
# Out:
# How many numbers will be in your list: 5
# Enter number 1 for the list: 9000
# Enter number 2 for the list: 84
# Enter number 3 for the list: 47
# Enter number 4 for the list: 46
# Enter number 5 for the list: 48
# The Average calculator of: [9000, 84, 47, 46, 48] is 47.0

# %% [markdown]
# ## Assignment 2: Parking Garage
#
# Write a program to compute the fee for parking in a garage for a number of hours.
#
# The program should:
# - Prompt the user for how many hours parked
# - Calculate the fee based on the following rules:
#   - $2.50/hour
#
#   - minimum fee is $6.00
#
#   - maximum fee is $20.00
# - Print the result
#
# For your program, define and use the following two functions:
# ```python
# # use input() to prompt for the # of hours parked, return this value
# def getParkingHours()
#
# # takes as input hours (a number), returns the parking fee
# def calcParkingFee()
# ```

# %%
def getParkingHours():
  hrs = int(input("How many hours did you park: "))
  return hrs

def calcParkingFee(hrs):
  hrlyCost = hrs * 2.50
  if hrlyCost < 6.00:
    return 6.00
  elif hrlyCost > 20.00:
    return 20.00
  else:
    return hrlyCost

def main():
  hrs = getParkingHours()
  fee = calcParkingFee(hrs)
  print(f"You parked {hrs} hours and it cost ${fee}")

main()
# Out:
# How many hours did you park: 6
# You parked 6 hours and it cost $15.0

# %% [markdown]
# ## Assignment 3: Tuition
#
# A college charges tuition according to the following:
# - 12 or more credits: $20,000/semester
#
# - 1-11 credits: $1,200 + $1,700 per credit
#
# Write a program that prompts the user for a number of credits and determines and displays the tuition for the semester. As part of your program, define and use the following function:
# ```python
# def calcTuition(credits)
# ```
# The function returns the tuition for a given number of credits

# %%
def calcTuition(credits):
  if credits >= 12:
    return 20000
  else:
    cost = 1200 + (credits * 1700)
    return cost

def main():
  credits = int(input("How many credits are you taking: "))
  cost = calcTuition(credits)
  print(f"The cost of attendance is ${cost}")

main()
# Out:
# How many credits are you taking: 11
# The cost of attendance is $19900
