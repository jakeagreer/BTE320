# %% [markdown]
# <a href="https://colab.research.google.com/github/jakeagreer/BTE320/blob/main/FirstClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
x=2
print(x+2)
# Out:
# Hello
# 4

# %%
x=2.0
x==2
# Out:
# True

# %%
13//4
# Out:
# 3

# %%
425%7
# Out:
# 5

# %%
4**3
# Out:
# 64
